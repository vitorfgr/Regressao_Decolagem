# %% [markdown]
# ## Biblioteca importadas

# %%
import numpy as np  
import pandas as pd 
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %% [markdown]
# ## Leitura das bases de dados de cada aeroportos

# %% [markdown]
# #### Frequencia de passageiros no aeroporto CWB

# %%
#nacional 
filename = r'C:Passageiros pagos\cwb_nac.xlsx'
cwb_nac = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

#internacional
filename = r'C:Passageiros pagos\cwb_int.xlsx'
cwb_int = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# #### Frequencia de passageiros no aeroporto IGU

# %%
#nacional
filename = r'C:Passageiros pagos\igu_nac.xlsx'
igu_nac = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

#internacional
filename = r'C:Passageiros pagos\igu_int.xlsx'
igu_int = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# #### Frequencia de passageiros no aeroporto NVT

# %%
#nacional
filename = r'C:Passageiros pagos\nvt_nac.xlsx'
nvt_nac = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

#internacional
filename = r'C:Passageiros pagos\nvt_int.xlsx'
nvt_int = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# #### Frequencia de passageiros no aeroporto PMW

# %%
filename = r'C:Passageiros pagos\pmw.xlsx'
pmw = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# #### Frequencia de passageiros no aeroporto SLZ

# %%
filename = r'C:Passageiros pagos\slz.xlsx'
slz = pd.read_excel(filename).drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# #### Frequencia de passageiros no aeroporto SJO

# %%
##nacional
#filename = r'C:\Users\vitor\OneDrive\Documentos\INSPER_JR\Decolagem_I\regressão\Passageiros pagos\sjo_nac.csv'
#dados7 = pd.read_csv(filename)

##internacional
#filename = r'C:\Users\vitor\OneDrive\Documentos\INSPER_JR\Decolagem_I\regressão\Passageiros pagos\sjo_int.csv'
#dados6 = pd.read_csv(filename)

# %% [markdown]
# ## Variaveis macro economicas

# %% [markdown]
# #### Valor do barril de petróleo

# %%
filename = r'C:Dados macros\statistic_id262858_opec-oil-price-annually-1960-2022.xlsx'
oil = pd.read_excel(filename)

# %% [markdown]
# #### Cotação do dolar

# %%
filename = r'C:Dados macros\Base de dados Dólar.xlsx'
dolar = pd.read_excel(filename)

# %% [markdown]
# #### Inflação do turismo no Brasil

# %%
filename = r'C:Dados macros\statistic_id270812_inflation-rate-in-brazil-2027.xlsx'
inflacao = pd.read_excel(filename)

# %% [markdown]
# #### PIB do Brasil e dos Estados dos aeroportos

# %%
filename = r'C:Dados macros\pib_real.xlsx'
pib = pd.read_excel(filename)

# %% [markdown]
# ## Analise exploratoria

# %% [markdown]
# ## Curitiba

# %% [markdown]
# ##### juntando os pontos macros e uma unico DataFrame

# %%
principal =(cwb_nac
 .join(oil.set_index('Ano'),on='Ano')
 .join(dolar.set_index('Ano'),on='Ano')
 .join(inflacao.set_index('Ano'),on='Ano')
 .join(pib.set_index('Ano'),on='Ano')
          )

# %% [markdown]
# #### Correlação entre os dados pré selecionados

# %%
principal= principal.loc[principal["Ano"]<2020]
principal.corr()
# Out:
#                       Ano  Passageiros     Preço     dolar  inflacao  \
# Ano              1.000000     0.825633  0.498046  0.462911 -0.379601
# Passageiros      0.825633     1.000000  0.757172  0.089808 -0.283610
# Preço            0.498046     0.757172  1.000000 -0.336762 -0.422720
# dolar            0.462911     0.089808 -0.336762  1.000000  0.166638
# inflacao        -0.379601    -0.283610 -0.422720  0.166638  1.000000
# PIB REAL BRASIL  0.934155     0.954258  0.739618  0.202944 -0.388362
# PIB REAL SP      0.898730     0.963111  0.768696  0.108461 -0.408767
# PIB REAL PR      0.963626     0.898470  0.617865  0.341305 -0.311484
# PIB REAL MA      0.971895     0.897959  0.629463  0.327593 -0.374915
# PIB REAL SC      0.964981     0.922975  0.663694  0.304972 -0.389976
# PIB REAL TO      0.986580     0.858229  0.506281  0.443775 -0.331505
#
#                  PIB REAL BRASIL  PIB REAL SP  PIB REAL PR  PIB REAL MA  \
# Ano                     0.934155     0.898730     0.963626     0.971895
# Passageiros             0.954258     0.963111     0.898470     0.897959
# Preço                   0.739618     0.768696     0.617865     0.629463
# dolar                   0.202944     0.108461     0.341305     0.327593
# inflacao               -0.388362    -0.408767    -0.311484    -0.374915
# PIB REAL BRASIL         1.000000     0.991895     0.975378     0.976990
# PIB REAL SP             0.991895     1.000000     0.951621     0.955459
# PIB REAL PR             0.975378     0.951621     1.000000     0.980245
# PIB REAL MA             0.976990     0.955459     0.980245     1.000000
# PIB REAL SC             0.988461     0.971014     0.985089     0.987955
# PIB REAL TO             0.943447     0.913279     0.978532     0.974010
#
#                  PIB REAL SC  PIB REAL TO
# Ano                 0.964981     0.986580
# Passageiros         0.922975     0.858229
# Preço               0.663694     0.506281
# dolar               0.304972     0.443775
# inflacao           -0.389976    -0.331505
# PIB REAL BRASIL     0.988461     0.943447
# PIB REAL SP         0.971014     0.913279
# PIB REAL PR         0.985089     0.978532
# PIB REAL MA         0.987955     0.974010
# PIB REAL SC         1.000000     0.976834
# PIB REAL TO         0.976834     1.000000

# %% [markdown]
# #### Análise grafica

# %%
fig, ax = plt.subplots(3,2)

fig.set_size_inches(15,10)



ax[0,0].plot(principal["Ano"], principal["Preço"], label='Petroleo')
ax[0,0].legend()

ax[1,0].plot(principal["Ano"], principal["dolar"], label = 'Cambio' )
ax[1,0].legend()

ax[0,1].plot(principal["Ano"], principal["inflacao"], label='Inflação')
ax[0,1].legend()

ax[2,0].plot(principal["Ano"], principal["PIB REAL BRASIL"], label = 'PIB Brasil' )
ax[2,0].legend()

ax[1,1].plot(principal["Ano"], principal["Passageiros"], label='Passageiros')
ax[1,1].legend()

plt.show()

# %% [markdown]
# ## Foz do Iguaçu

# %% [markdown]
# ##### juntando os pontos macros e uma unico DataFrame

# %%
principal =(igu_nac
 .join(oil.set_index('Ano'),on='Ano')
 .join(dolar.set_index('Ano'),on='Ano')
 .join(inflacao.set_index('Ano'),on='Ano')
 .join(pib.set_index('Ano'),on='Ano')
          )

# %% [markdown]
# ##### Correlação entre os dados pré selecionados

# %%
principal= principal.loc[principal["Ano"]<2020]
principal.corr()
# Out:
#                       Ano  Passageiros     Preço     dolar  inflacao  \
# Ano              1.000000     0.965459  0.498046  0.462911 -0.379601
# Passageiros      0.965459     1.000000  0.477749  0.490011 -0.329348
# Preço            0.498046     0.477749  1.000000 -0.336762 -0.422720
# dolar            0.462911     0.490011 -0.336762  1.000000  0.166638
# inflacao        -0.379601    -0.329348 -0.422720  0.166638  1.000000
# PIB REAL BRASIL  0.934155     0.906031  0.739618  0.202944 -0.388362
# PIB REAL SP      0.898730     0.866309  0.768696  0.108461 -0.408767
# PIB REAL PR      0.963626     0.940676  0.617865  0.341305 -0.311484
# PIB REAL MA      0.971895     0.943954  0.629463  0.327593 -0.374915
# PIB REAL SC      0.964981     0.948191  0.663694  0.304972 -0.389976
# PIB REAL TO      0.986580     0.973040  0.506281  0.443775 -0.331505
#
#                  PIB REAL BRASIL  PIB REAL SP  PIB REAL PR  PIB REAL MA  \
# Ano                     0.934155     0.898730     0.963626     0.971895
# Passageiros             0.906031     0.866309     0.940676     0.943954
# Preço                   0.739618     0.768696     0.617865     0.629463
# dolar                   0.202944     0.108461     0.341305     0.327593
# inflacao               -0.388362    -0.408767    -0.311484    -0.374915
# PIB REAL BRASIL         1.000000     0.991895     0.975378     0.976990
# PIB REAL SP             0.991895     1.000000     0.951621     0.955459
# PIB REAL PR             0.975378     0.951621     1.000000     0.980245
# PIB REAL MA             0.976990     0.955459     0.980245     1.000000
# PIB REAL SC             0.988461     0.971014     0.985089     0.987955
# PIB REAL TO             0.943447     0.913279     0.978532     0.974010
#
#                  PIB REAL SC  PIB REAL TO
# Ano                 0.964981     0.986580
# Passageiros         0.948191     0.973040
# Preço               0.663694     0.506281
# dolar               0.304972     0.443775
# inflacao           -0.389976    -0.331505
# PIB REAL BRASIL     0.988461     0.943447
# PIB REAL SP         0.971014     0.913279
# PIB REAL PR         0.985089     0.978532
# PIB REAL MA         0.987955     0.974010
# PIB REAL SC         1.000000     0.976834
# PIB REAL TO         0.976834     1.000000

# %% [markdown]
# ##### Análise grafica

# %%
fig, ax = plt.subplots(3,2)

fig.set_size_inches(15,10)



ax[0,0].plot(principal["Ano"], principal["Preço"], label='Petroleo')
ax[0,0].legend()

ax[1,0].plot(principal["Ano"], principal["dolar"], label = 'Cambio' )
ax[1,0].legend()

ax[0,1].plot(principal["Ano"], principal["inflacao"], label='Inflação')
ax[0,1].legend()

ax[2,0].plot(principal["Ano"], principal["PIB REAL BRASIL"], label = 'PIB Brasil' )
ax[2,0].legend()

ax[1,1].plot(principal["Ano"], principal["Passageiros"], label='Passageiros')
ax[1,1].legend()

plt.show()

# %% [markdown]
# ## Navegantes

# %% [markdown]
# ##### juntando os pontos macros e uma unico DataFrame

# %%
principal =(nvt_nac
 .join(oil.set_index('Ano'),on='Ano')
 .join(dolar.set_index('Ano'),on='Ano')
 .join(inflacao.set_index('Ano'),on='Ano')
 .join(pib.set_index('Ano'),on='Ano')
          )

# %% [markdown]
# ##### Correlação entre os dados pré selecionados

# %%
principal= principal.loc[principal["Ano"]<2020]
principal.corr()
# Out:
#                       Ano  Passageiros     Preço     dolar  inflacao  \
# Ano              1.000000     0.874199  0.498046  0.462911 -0.379601
# Passageiros      0.874199     1.000000  0.326950  0.522662 -0.296078
# Preço            0.498046     0.326950  1.000000 -0.336762 -0.422720
# dolar            0.462911     0.522662 -0.336762  1.000000  0.166638
# inflacao        -0.379601    -0.296078 -0.422720  0.166638  1.000000
# PIB REAL BRASIL  0.934155     0.786511  0.739618  0.202944 -0.388362
# PIB REAL SP      0.898730     0.749122  0.768696  0.108461 -0.408767
# PIB REAL PR      0.963626     0.840185  0.617865  0.341305 -0.311484
# PIB REAL MA      0.971895     0.843963  0.629463  0.327593 -0.374915
# PIB REAL SC      0.964981     0.854746  0.663694  0.304972 -0.389976
# PIB REAL TO      0.986580     0.910825  0.506281  0.443775 -0.331505
#
#                  PIB REAL BRASIL  PIB REAL SP  PIB REAL PR  PIB REAL MA  \
# Ano                     0.934155     0.898730     0.963626     0.971895
# Passageiros             0.786511     0.749122     0.840185     0.843963
# Preço                   0.739618     0.768696     0.617865     0.629463
# dolar                   0.202944     0.108461     0.341305     0.327593
# inflacao               -0.388362    -0.408767    -0.311484    -0.374915
# PIB REAL BRASIL         1.000000     0.991895     0.975378     0.976990
# PIB REAL SP             0.991895     1.000000     0.951621     0.955459
# PIB REAL PR             0.975378     0.951621     1.000000     0.980245
# PIB REAL MA             0.976990     0.955459     0.980245     1.000000
# PIB REAL SC             0.988461     0.971014     0.985089     0.987955
# PIB REAL TO             0.943447     0.913279     0.978532     0.974010
#
#                  PIB REAL SC  PIB REAL TO
# Ano                 0.964981     0.986580
# Passageiros         0.854746     0.910825
# Preço               0.663694     0.506281
# dolar               0.304972     0.443775
# inflacao           -0.389976    -0.331505
# PIB REAL BRASIL     0.988461     0.943447
# PIB REAL SP         0.971014     0.913279
# PIB REAL PR         0.985089     0.978532
# PIB REAL MA         0.987955     0.974010
# PIB REAL SC         1.000000     0.976834
# PIB REAL TO         0.976834     1.000000

# %% [markdown]
# ##### Análise grafica

# %%
fig, ax = plt.subplots(3,2)

fig.set_size_inches(15,10)



ax[0,0].plot(principal["Ano"], principal["Preço"], label='Petroleo')
ax[0,0].legend()

ax[1,0].plot(principal["Ano"], principal["dolar"], label = 'Cambio' )
ax[1,0].legend()

ax[0,1].plot(principal["Ano"], principal["inflacao"], label='Inflação')
ax[0,1].legend()

ax[2,0].plot(principal["Ano"], principal["PIB REAL BRASIL"], label = 'PIB Brasil' )
ax[2,0].legend()

ax[1,1].plot(principal["Ano"], principal["Passageiros"], label='Passageiros')
ax[1,1].legend()

plt.show()

# %% [markdown]
# ## Palmas

# %% [markdown]
# ##### juntando os pontos macros e uma unico DataFrame

# %%
principal =(pmw
 .join(oil.set_index('Ano'),on='Ano')
 .join(dolar.set_index('Ano'),on='Ano')
 .join(inflacao.set_index('Ano'),on='Ano')
 .join(pib.set_index('Ano'),on='Ano')
          )

# %% [markdown]
# ##### Correlação entre os dados pré selecionados

# %%
principal= principal.loc[principal["Ano"]<2020]
principal.corr()
# Out:
#                       Ano  Passageiros     Preço     dolar  inflacao  \
# Ano              1.000000     0.942935  0.498046  0.462911 -0.379601
# Passageiros      0.942935     1.000000  0.546518  0.365772 -0.344995
# Preço            0.498046     0.546518  1.000000 -0.336762 -0.422720
# dolar            0.462911     0.365772 -0.336762  1.000000  0.166638
# inflacao        -0.379601    -0.344995 -0.422720  0.166638  1.000000
# PIB REAL BRASIL  0.934155     0.937534  0.739618  0.202944 -0.388362
# PIB REAL SP      0.898730     0.915110  0.768696  0.108461 -0.408767
# PIB REAL PR      0.963626     0.960565  0.617865  0.341305 -0.311484
# PIB REAL MA      0.971895     0.969253  0.629463  0.327593 -0.374915
# PIB REAL SC      0.964981     0.962425  0.663694  0.304972 -0.389976
# PIB REAL TO      0.986580     0.963334  0.506281  0.443775 -0.331505
#
#                  PIB REAL BRASIL  PIB REAL SP  PIB REAL PR  PIB REAL MA  \
# Ano                     0.934155     0.898730     0.963626     0.971895
# Passageiros             0.937534     0.915110     0.960565     0.969253
# Preço                   0.739618     0.768696     0.617865     0.629463
# dolar                   0.202944     0.108461     0.341305     0.327593
# inflacao               -0.388362    -0.408767    -0.311484    -0.374915
# PIB REAL BRASIL         1.000000     0.991895     0.975378     0.976990
# PIB REAL SP             0.991895     1.000000     0.951621     0.955459
# PIB REAL PR             0.975378     0.951621     1.000000     0.980245
# PIB REAL MA             0.976990     0.955459     0.980245     1.000000
# PIB REAL SC             0.988461     0.971014     0.985089     0.987955
# PIB REAL TO             0.943447     0.913279     0.978532     0.974010
#
#                  PIB REAL SC  PIB REAL TO
# Ano                 0.964981     0.986580
# Passageiros         0.962425     0.963334
# Preço               0.663694     0.506281
# dolar               0.304972     0.443775
# inflacao           -0.389976    -0.331505
# PIB REAL BRASIL     0.988461     0.943447
# PIB REAL SP         0.971014     0.913279
# PIB REAL PR         0.985089     0.978532
# PIB REAL MA         0.987955     0.974010
# PIB REAL SC         1.000000     0.976834
# PIB REAL TO         0.976834     1.000000

# %% [markdown]
# ##### Análise grafica

# %%
fig, ax = plt.subplots(3,2)

fig.set_size_inches(15,10)



ax[0,0].plot(principal["Ano"], principal["Preço"], label='Petroleo')
ax[0,0].legend()

ax[1,0].plot(principal["Ano"], principal["dolar"], label = 'Cambio' )
ax[1,0].legend()

ax[0,1].plot(principal["Ano"], principal["inflacao"], label='Inflação')
ax[0,1].legend()

ax[2,0].plot(principal["Ano"], principal["PIB REAL BRASIL"], label = 'PIB Brasil' )
ax[2,0].legend()

ax[1,1].plot(principal["Ano"], principal["Passageiros"], label='Passageiros')
ax[1,1].legend()

plt.show()

# %% [markdown]
# ## São Luiz

# %% [markdown]
# ##### juntando os pontos macros e uma unico DataFrame

# %%
principal =(slz
 .join(oil.set_index('Ano'),on='Ano')
 .join(dolar.set_index('Ano'),on='Ano')
 .join(inflacao.set_index('Ano'),on='Ano')
 .join(pib.set_index('Ano'),on='Ano')
          )

# %% [markdown]
# ##### Correlação entre os dados pré selecionados

# %%
principal= principal.loc[principal["Ano"]<2020]
principal.corr()
# Out:
#                       Ano  Passageiros     Preço     dolar  inflacao  \
# Ano              1.000000     0.963178  0.498046  0.462911 -0.379601
# Passageiros      0.963178     1.000000  0.474653  0.495322 -0.325744
# Preço            0.498046     0.474653  1.000000 -0.336762 -0.422720
# dolar            0.462911     0.495322 -0.336762  1.000000  0.166638
# inflacao        -0.379601    -0.325744 -0.422720  0.166638  1.000000
# PIB REAL BRASIL  0.934155     0.902445  0.739618  0.202944 -0.388362
# PIB REAL SP      0.898730     0.861388  0.768696  0.108461 -0.408767
# PIB REAL PR      0.963626     0.938018  0.617865  0.341305 -0.311484
# PIB REAL MA      0.971895     0.942201  0.629463  0.327593 -0.374915
# PIB REAL SC      0.964981     0.945292  0.663694  0.304972 -0.389976
# PIB REAL TO      0.986580     0.970358  0.506281  0.443775 -0.331505
#
#                  PIB REAL BRASIL  PIB REAL SP  PIB REAL PR  PIB REAL MA  \
# Ano                     0.934155     0.898730     0.963626     0.971895
# Passageiros             0.902445     0.861388     0.938018     0.942201
# Preço                   0.739618     0.768696     0.617865     0.629463
# dolar                   0.202944     0.108461     0.341305     0.327593
# inflacao               -0.388362    -0.408767    -0.311484    -0.374915
# PIB REAL BRASIL         1.000000     0.991895     0.975378     0.976990
# PIB REAL SP             0.991895     1.000000     0.951621     0.955459
# PIB REAL PR             0.975378     0.951621     1.000000     0.980245
# PIB REAL MA             0.976990     0.955459     0.980245     1.000000
# PIB REAL SC             0.988461     0.971014     0.985089     0.987955
# PIB REAL TO             0.943447     0.913279     0.978532     0.974010
#
#                  PIB REAL SC  PIB REAL TO
# Ano                 0.964981     0.986580
# Passageiros         0.945292     0.970358
# Preço               0.663694     0.506281
# dolar               0.304972     0.443775
# inflacao           -0.389976    -0.331505
# PIB REAL BRASIL     0.988461     0.943447
# PIB REAL SP         0.971014     0.913279
# PIB REAL PR         0.985089     0.978532
# PIB REAL MA         0.987955     0.974010
# PIB REAL SC         1.000000     0.976834
# PIB REAL TO         0.976834     1.000000

# %% [markdown]
# ##### Análise grafica

# %%
fig, ax = plt.subplots(3,2)

fig.set_size_inches(15,10)



ax[0,0].plot(principal["Ano"], principal["Preço"], label='Petroleo')
ax[0,0].legend()

ax[1,0].plot(principal["Ano"], principal["dolar"], label = 'Cambio' )
ax[1,0].legend()

ax[0,1].plot(principal["Ano"], principal["inflacao"], label='Inflação')
ax[0,1].legend()

ax[2,0].plot(principal["Ano"], principal["PIB REAL BRASIL"], label = 'PIB Brasil' )
ax[2,0].legend()

ax[1,1].plot(principal["Ano"], principal["Passageiros"], label='Passageiros')
ax[1,1].legend()

plt.show()

# %% [markdown]
# ## Comparação de passageiros nos aeroportos analisados

# %%
plt.plot(cwb_nac["Ano"], cwb_nac["Passageiros"], label='Curitiba')
plt.legend()

plt.plot(igu_nac["Ano"], igu_nac["Passageiros"], label='Foz do Iguaçu')
plt.legend()
#
plt.plot(nvt_nac["Ano"], nvt_nac["Passageiros"], label='Navegantes')
plt.legend()
#
plt.plot(slz["Ano"], slz["Passageiros"], label='São Luiz')
plt.legend()
#
plt.plot(pmw["Ano"], pmw["Passageiros"], label='Palmas')
plt.legend()



plt.show()
